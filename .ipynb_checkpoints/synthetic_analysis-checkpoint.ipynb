# %%
import numpy as np
import matplotlib.pyplot as plt
import mdsine2 as md2
from mdsine2.names import STRNAMES
import pickle
from sklearn import linear_model as lm
# Out:
# [DEBUG] Using default logger (stdout, stderr).

# %%
npzfile = np.load("datasets/synthetic/glv.npz")
npzfile
# Out:
# NpzFile 'datasets/synthetic/glv.npz' with keys: growth_rates, interactions, initial_mean, initial_std

# %%
gr = npzfile["growth_rates"]
ints = npzfile["interactions"]

# %%
plt.imshow(ints, cmap="coolwarm", vmin=-np.max(np.abs(ints)), vmax=np.max(np.abs(ints)))
plt.colorbar()

# %%
plt.imshow(np.sign(ints), cmap="coolwarm")

# %%
with open("datasets/synthetic/output/reads_25000/trial_0/low_noise/mdsine2/simulated-low/mcmc.pkl", "rb") as file:
    mcmc = pickle.load(file)

# %%
gr_est = md2.summary(mcmc.graph[STRNAMES.GLV_PARAMETERS].growth)["mean"]

# %%
gr_est
# Out:
# array([0.36430787, 0.43626347, 0.43511119, 0.53575179, 0.38949897,
#        0.33284466, 0.16233175, 0.34434012, 0.79773693, 0.48028944])

# %%
md2.summary(mcmc.graph[STRNAMES.SELF_INTERACTION_VALUE])["mean"]
# Out:
# array([9.33064384e-06, 2.14360959e-05, 3.60802594e-05, 1.66956374e-05,
#        2.21897536e-05, 2.56145508e-05, 1.72721980e-05, 3.46455660e-05,
#        1.95463384e-05, 4.32068071e-05])

# %%
gr_est = md2.summary(mcmc.graph[STRNAMES.GROWTH_VALUE])["median"]

# %%
mcmc

# %%
plt.plot(gr)
plt.plot(gr_est)

# %%
ints_est = md2.summary(mcmc.graph[STRNAMES.INTERACTIONS_OBJ].get_trace_from_disk())["mean"]-np.diag(md2.summary(mcmc.graph[STRNAMES.SELF_INTERACTION_VALUE].get_trace_from_disk())["mean"])

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,6))

im1 = ax[0].imshow(ints, cmap="coolwarm", vmin=-np.max(np.abs(ints)), vmax=np.max(np.abs(ints)))
fig.colorbar(im1)

im2 = ax[1].imshow(ints_est, cmap="coolwarm", vmin=-np.max(np.abs(ints_est)), vmax=np.max(np.abs(ints_est)))
fig.colorbar(im2)

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,6))

im1 = ax[0].imshow(ints, cmap="coolwarm", vmin=-np.max(np.abs(ints)), vmax=np.max(np.abs(ints)))
fig.colorbar(im1)

im2 = ax[1].imshow(ints_est*(md2.generate_interation_bayes_factors_posthoc(mcmc, )>10)+np.diag(np.diag(ints_est)), cmap="coolwarm", vmin=-np.max(np.abs(ints_est)), vmax=np.max(np.abs(ints_est)))
fig.colorbar(im2)

# %%
from scipy.stats import spearmanr, pearsonr

# %%
spearmanr(gr, gr_est)
# Out:
# SignificanceResult(statistic=np.float64(-0.1515151515151515), pvalue=np.float64(0.6760651759978539))

# %%
mcmc.graph[STRNAMES.PROCESSVAR].get_trace_from_disk().mean()
# Out:
# np.float64(0.19012891907758775)

# %%
spearmanr((ints).flatten(), (ints_est).flatten())
# Out:
# SignificanceResult(statistic=np.float64(0.66712359197748), pvalue=np.float64(3.4998005438560444e-14))

# %%
spearmanr((ints-np.diag(np.diag(ints))).flatten(), (ints_est-np.diag(np.diag(ints_est))).flatten())
# Out:
# SignificanceResult(statistic=np.float64(0.5535974798769446), pvalue=np.float64(2.3167629557750118e-09))

# %%
spearmanr((ints-np.diag(np.diag(ints))).flatten(), ((ints_est-np.diag(np.diag(ints_est)))*(md2.generate_interation_bayes_factors_posthoc(mcmc)>10)).flatten())
# Out:
# SignificanceResult(statistic=np.float64(0.747881320660978), pvalue=np.float64(3.888298164136079e-19))

# %%
spearmanr((ints).flatten(), ((ints_est-np.diag(np.diag(ints_est)))*(md2.generate_interation_bayes_factors_posthoc(mcmc)>10)+np.diag(np.diag(ints_est))).flatten())
# Out:
# SignificanceResult(statistic=np.float64(0.8226865066386722), pvalue=np.float64(8.93653331197679e-26))

# %%
pearsonr((ints-np.diag(np.diag(ints))).flatten(), (ints_est-np.diag(np.diag(ints_est))).flatten())
# Out:
# PearsonRResult(statistic=np.float64(0.7400269014111068), pvalue=np.float64(1.4164075709595746e-18))

# %%
pearsonr((ints-np.diag(np.diag(ints))).flatten(), ((ints_est-np.diag(np.diag(ints_est)))*(md2.generate_interation_bayes_factors_posthoc(mcmc)>10)).flatten())
# Out:
# PearsonRResult(statistic=np.float64(0.7883897417554289), pvalue=np.float64(2.1272455995785715e-22))

# %%
plt.imshow(np.sign(ints_est), cmap="coolwarm")

# %%
plt.imshow(np.sign(ints)+np.eye(10), cmap="coolwarm")

# %%
plt.imshow(np.sign(ints_est)*(md2.generate_interation_bayes_factors_posthoc(mcmc)>10), cmap="coolwarm")

# %% [markdown]
# ---

# %%
with open("datasets/synthetic/data/trial_0/reads_25000/noise_low/subjset.pkl", "rb") as file:
    subjset = pickle.load(file)

# %%
list(subjset[0].qpcr.values())[0].data.mean()
# Out:
# np.float64(77189.50018967286)

# %%
t = subjset[0].times

# %%
plt.plot(subjset[0].matrix()["abs"].T)
plt.plot(X[:26]/25000, "--")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.plot(subjset[0].matrix()["abs"].T)
#       2 plt.plot(X[:26]/25000, "--")
#
# NameError: name 'plt' is not defined

# %%
reads = np.array(list(subjset[0].reads.values()))
qpcr = np.array([i.data.mean() for i in subjset[0].qpcr.values()])

X = reads*qpcr.reshape((-1,1))

dX = np.diff(X, axis=0)
X = X[:-1]

for i in range(1, 10):
    reads = np.array(list(subjset[i].reads.values()))
    qpcr = np.array([k.data.mean() for k in subjset[i].qpcr.values()])

    x = reads*qpcr.reshape((-1,1))
    dx = np.diff(x, axis=0)

    X = np.concatenate([X, x[:-1]], axis=0)
    dX = np.concatenate([dX, dx], axis=0)

# %%
plt.plot(X)
plt.yscale("log")

# %%
reg = lm.LinearRegression(fit_intercept=False)

# %%
Aest = np.zeros((10,11))

for i in range(10):
    feats = np.hstack([X[i*26:(i+1)*26,[i]], X[i*26:(i+1)*26,[i]]*X[i*26:(i+1)*26]])
    reg.fit(feats, dX[i*26:(i+1)*26,i]/np.diff(t))
    Aest[i] = reg.coef_

# %%
reg.coef_
# Out:
# array([ 9.48773575e-01, -1.31326100e-11,  3.18133436e-10,  7.33752428e-10,
#         2.40148463e-08, -3.55152920e-09,  2.24261245e-10,  7.63313390e-10,
#         1.79321841e-10,  1.31121812e-09, -3.72888731e-09])

# %%
plt.plot(gr)
plt.plot(gr_est)
# plt.plot(Aest[:,0])

# %%
plt.imshow(Aest[:,1:], cmap="coolwarm", vmin=-np.max(np.abs(Aest[:,1:])), vmax=np.max(np.abs(Aest[:,1:])))
plt.colorbar()

# %%
spearmanr(ints.flatten(), Aest[:,1:].flatten())
# Out:
# SignificanceResult(statistic=np.float64(0.11891462709197459), pvalue=np.float64(0.23864425088852864))

# %%
traces = h5py.File("datasets/synthetic/output/reads_25000/trial_0/low_noise/mdsine2/simulated-low/traces.hdf5", "r")

# %%
fig, ax = plt.subplots(2, 5, figsize=(20,4))

for i in range(10):
    ax.flatten()[i].plot(subjset[i].matrix()["abs"].T[:,0])
    ax1 = ax.flatten()[i].twinx()
    ax1.plot(md2.summary(np.array(traces[STRNAMES.LATENT_TRAJECTORY+f"_subj_{i}"]))["mean"].T[:,0], c="k")
    ax1.fill_between(np.arange(27), *np.percentile(np.array(traces[STRNAMES.LATENT_TRAJECTORY+f"_subj_{i}"]), [5,95], axis=0)[:,0], color="k", alpha=0.3)

# %%
mcmc.graph[STRNAMES.INTERACTIONS_OBJ].get_trace_from_disk()
# Out:
# array([[[            nan,  1.78576032e-06,             nan, ...,
#           2.39543452e-05,  2.07737069e-05,             nan],
#         [            nan,             nan,  3.00654147e-05, ...,
#                      nan, -4.12574660e-05,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,             nan, -1.10135211e-06],
#         ...,
#         [-1.01077415e-05,             nan,             nan, ...,
#                      nan, -1.33900051e-05,             nan],
#         [            nan, -2.38185633e-05, -8.25411814e-05, ...,
#                      nan,             nan,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan, -5.17278481e-05,             nan]],
#
#        [[            nan,             nan,             nan, ...,
#           2.26738665e-05,             nan,             nan],
#         [            nan,             nan,  3.25515172e-05, ...,
#                      nan, -4.89623378e-05,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,  6.88987478e-06,             nan],
#         ...,
#         [-8.96374556e-06,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         [            nan, -3.23801520e-05, -7.78937755e-05, ...,
#                      nan,             nan,             nan],
#         [-1.66005784e-06,             nan,             nan, ...,
#          -1.09278855e-06, -3.48628756e-05,             nan]],
#
#        [[            nan,             nan,             nan, ...,
#           2.78087550e-05,             nan, -7.24932264e-06],
#         [            nan,             nan,  2.81805390e-05, ...,
#                      nan, -3.57634824e-05, -2.46577892e-06],
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         ...,
#         [-8.45496364e-06,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         [            nan, -2.90829058e-05, -7.94642177e-05, ...,
#                      nan,             nan,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan, -3.05571896e-05,             nan]],
#
#        ...,
#
#        [[            nan,             nan,  7.16111822e-07, ...,
#           2.78305449e-05,  1.85581957e-05,             nan],
#         [ 3.48296283e-06,             nan,  1.46511358e-05, ...,
#                      nan, -3.55437479e-05, -1.92649652e-05],
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         ...,
#         [-9.31384046e-06,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         [ 9.04435968e-06, -3.90755720e-05, -6.59434146e-05, ...,
#                      nan,             nan,  2.62413428e-05],
#         [            nan,             nan,             nan, ...,
#                      nan, -3.56756324e-05,             nan]],
#
#        [[            nan,             nan,             nan, ...,
#           2.68708143e-05,             nan,             nan],
#         [ 7.44711693e-06,             nan,  1.85143769e-05, ...,
#          -7.34938368e-06, -3.32772681e-05, -1.39996968e-05],
#         [ 4.33574892e-06,             nan,             nan, ...,
#                      nan, -1.64100974e-08,             nan],
#         ...,
#         [-9.07607012e-06,             nan, -5.71222069e-06, ...,
#                      nan,             nan,             nan],
#         [ 7.42916026e-06, -3.78810427e-05, -7.58183554e-05, ...,
#                      nan,             nan,  2.89818070e-05],
#         [            nan,             nan,             nan, ...,
#          -7.51098618e-06, -2.97601183e-05,             nan]],
#
#        [[            nan,             nan, -3.69373316e-07, ...,
#           1.60400216e-05,             nan,             nan],
#         [            nan,             nan,  2.56105634e-05, ...,
#                      nan, -5.01005951e-05,             nan],
#         [            nan, -4.03857639e-06,             nan, ...,
#                      nan,             nan,             nan],
#         ...,
#         [-1.10756911e-05,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         [            nan, -4.05938295e-05, -5.88535854e-05, ...,
#                      nan,             nan,  2.85818102e-05],
#         [            nan,             nan,             nan, ...,
#          -1.11827344e-05, -3.59035640e-05,             nan]]],
#       shape=(10000, 10, 10))

# %%
np.array(traces[STRNAMES.INTERACTIONS_OBJ])
# Out:
# array([[[            nan,             nan,             nan, ...,
#                      nan,  7.05058680e-05,  3.53410989e-06],
#         [ 3.75526275e-06,             nan,  1.67854612e-05, ...,
#           6.91764937e-06, -1.50069807e-05, -1.26804667e-05],
#         [            nan,             nan,             nan, ...,
#           1.08415800e-05,             nan, -1.92786562e-06],
#         ...,
#         [-8.26420349e-06,             nan,             nan, ...,
#                      nan,  2.04172804e-05,             nan],
#         [            nan, -1.33304565e-05, -5.51636450e-05, ...,
#           3.00797493e-06,             nan,  3.65481062e-05],
#         [-3.27071751e-07,             nan,  1.08964259e-05, ...,
#                      nan, -1.60326013e-05,             nan]],
#
#        [[            nan,             nan,             nan, ...,
#           4.73747132e-06,  1.92314645e-05,             nan],
#         [            nan,             nan,  2.84400297e-05, ...,
#           1.08674841e-06,  3.34457691e-06,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         ...,
#         [-8.33834992e-06,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         [            nan,  6.45064574e-06, -4.13435960e-05, ...,
#           1.21544671e-05,             nan,             nan],
#         [            nan,             nan,  2.11623698e-05, ...,
#          -2.83953367e-05,  7.60233344e-07,             nan]],
#
#        [[            nan,             nan,             nan, ...,
#                      nan,  1.88847970e-06, -1.71158701e-05],
#         [ 3.45958354e-06,             nan,             nan, ...,
#                      nan,  6.95844804e-06,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,  6.47856939e-06, -1.37863152e-05],
#         ...,
#         [-1.19851694e-05,             nan,             nan, ...,
#                      nan,             nan,  3.29305666e-06],
#         [            nan,             nan, -2.69825103e-05, ...,
#                      nan,             nan,  7.41909509e-06],
#         [            nan,             nan,  9.63809575e-06, ...,
#                      nan,  3.37676171e-06,             nan]],
#
#        ...,
#
#        [[            nan,             nan,  7.16111822e-07, ...,
#           2.78305449e-05,  1.85581957e-05,             nan],
#         [ 3.48296283e-06,             nan,  1.46511358e-05, ...,
#                      nan, -3.55437479e-05, -1.92649652e-05],
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         ...,
#         [-9.31384046e-06,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         [ 9.04435968e-06, -3.90755720e-05, -6.59434146e-05, ...,
#                      nan,             nan,  2.62413428e-05],
#         [            nan,             nan,             nan, ...,
#                      nan, -3.56756324e-05,             nan]],
#
#        [[            nan,             nan,             nan, ...,
#           2.68708143e-05,             nan,             nan],
#         [ 7.44711693e-06,             nan,  1.85143769e-05, ...,
#          -7.34938368e-06, -3.32772681e-05, -1.39996968e-05],
#         [ 4.33574892e-06,             nan,             nan, ...,
#                      nan, -1.64100974e-08,             nan],
#         ...,
#         [-9.07607012e-06,             nan, -5.71222069e-06, ...,
#                      nan,             nan,             nan],
#         [ 7.42916026e-06, -3.78810427e-05, -7.58183554e-05, ...,
#                      nan,             nan,  2.89818070e-05],
#         [            nan,             nan,             nan, ...,
#          -7.51098618e-06, -2.97601183e-05,             nan]],
#
#        [[            nan,             nan, -3.69373316e-07, ...,
#           1.60400216e-05,             nan,             nan],
#         [            nan,             nan,  2.56105634e-05, ...,
#                      nan, -5.01005951e-05,             nan],
#         [            nan, -4.03857639e-06,             nan, ...,
#                      nan,             nan,             nan],
#         ...,
#         [-1.10756911e-05,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         [            nan, -4.05938295e-05, -5.88535854e-05, ...,
#                      nan,             nan,  2.85818102e-05],
#         [            nan,             nan,             nan, ...,
#          -1.11827344e-05, -3.59035640e-05,             nan]]],
#       shape=(15000, 10, 10))

# %%
plt.hist(mcmc.graph[STRNAMES.CLUSTER_INTERACTION_INDICATOR_PROB].get_trace_from_disk(section="posterior"), 20)
# Out:
# (array([   4.,   17.,   48.,  154.,  358.,  636.,  965., 1168., 1384.,
#         1409., 1210.,  957.,  724.,  445.,  239.,  140.,   77.,   38.,
#           21.,    6.]),
#  array([0.12354883, 0.14704687, 0.17054491, 0.19404294, 0.21754098,
#         0.24103902, 0.26453706, 0.28803509, 0.31153313, 0.33503117,
#         0.3585292 , 0.38202724, 0.40552528, 0.42902331, 0.45252135,
#         0.47601939, 0.49951743, 0.52301546, 0.5465135 , 0.57001154,
#         0.59350957]),
#  <BarContainer object of 20 artists>)

# %%
traces[STRNAMES.PRIOR]
# Out:
# <HDF5 dataset "Cluster interaction probability": shape (15000,), type "<f8">

# %%
def generate_interation_bayes_factors_posthoc(traces):
    '''Generates the bayes factors on an item-item level for the interactions,
    given the passed in prior. All negative indicators are set as `np.nan`s in
    the trace, so we do `~np.isnan` to get the indicators.

    Since the prior is conjugate, we can fully integrate out the prior of the
    calculation:
        bf[i,j] = (count_on[i,j] * b) / (count_off[i,j] * a)

    Parameters
    ----------
    mcmc : mdsine2.BaseMCMC
        This is the inference object containing the traces
    section : str
        This is the section of the MH samples to take the samples

    Returns
    -------
    np.ndarray((n,n), dtype=float)
        These are the bayes factors for each of the interactions on an item-item level
    '''
    # interactions = mcmc.graph[STRNAMES.INTERACTIONS_OBJ]
    # trace = interactions.get_trace_from_disk(section=section)

    trace = traces[STRNAMES.INTERACTIONS_OBJ]
    
    trace = ~ np.isnan(trace)
    cnts_1 = np.sum(trace, axis=0)
    cnts_0 = np.sum(1-trace, axis=0)

    return cnts_1/cnts_0
    
    # print(cnts_1)
    # print()
    # print(cnts_0)

    # a = mcmc.graph[STRNAMES.CLUSTER_INTERACTION_INDICATOR_PROB].prior.a.value
    # b = mcmc.graph[STRNAMES.CLUSTER_INTERACTION_INDICATOR_PROB].prior.b.value

    # return (cnts_1 * b) / (cnts_0 * a)

# %%
plt.imshow(generate_interation_bayes_factors_posthoc(traces)>10)

# %%
plt.imshow(md2.generate_interation_bayes_factors_posthoc(mcmc)>10)

# %% [markdown]
# ---

# %%
import h5py

# %%
traces = h5py.File("datasets/synthetic_rel/output/reads_25000/trial_0/low_noise/mdsine2/simulated-low/traces.hdf5", "r")

# %%
traces.keys()
# Out:
# <KeysViewHDF5 ['Cluster interaction indicator parameter', 'Cluster interaction probability', 'Growth parameter', 'Interactions object', 'Latent trajectory parameter_subj_0', 'Latent trajectory parameter_subj_1', 'Latent trajectory parameter_subj_2', 'Latent trajectory parameter_subj_3', 'Latent trajectory parameter_subj_4', 'Latent trajectory parameter_subj_5', 'Latent trajectory parameter_subj_6', 'Latent trajectory parameter_subj_7', 'Latent trajectory parameter_subj_8', 'Latent trajectory parameter_subj_9', 'Mean parameter for the normal prior of the interaction parameter', 'Mean parameter for the truncated normal prior of the growth parameter', 'Mean parameter for the truncated normal prior of the self-interaction parameter', 'Process Variance parameter', 'Self interaction parameter', 'Variance parameter for the normal prior of the interaction parameter']>

# %%
gr_est = md2.summary(np.array(traces[STRNAMES.GROWTH_VALUE]))["mean"]

# %%
ints_est = md2.summary(np.array(traces[STRNAMES.INTERACTIONS_OBJ]))["mean"]-np.diag(md2.summary(np.array(traces[STRNAMES.SELF_INTERACTION_VALUE]))["mean"])

# %%
plt.plot(gr)
plt.plot(gr_est)

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,6))

im1 = ax[0].imshow(ints, cmap="coolwarm", vmin=-np.max(np.abs(ints)), vmax=np.max(np.abs(ints)))
fig.colorbar(im1)

im2 = ax[1].imshow(ints_est, cmap="coolwarm", vmin=-np.max(np.abs(ints_est)), vmax=np.max(np.abs(ints_est)))
fig.colorbar(im2)

# %%
np.array([i.data.mean() for i in subjset[0].qpcr.values()])
# Out:
# array([ 77189.50018967,  74452.57932821,  81529.1117437 ,  76881.26722638,
#         86974.43326153, 109198.04450948, 111153.21541803, 114289.01848602,
#        105792.75882137,  93158.58152607,  83726.19225515,  97628.90583477,
#         88560.61697251,  81100.42205247,  72447.03242764,  76500.26990555,
#         94478.82573025, 101183.08610252, 127073.36823333, 146989.53553088,
#        138724.92689755, 123721.80415199, 100875.71272267, 100851.50335499,
#         92173.61166994,  93129.35079767,  82624.22022835])

# %%
plt.plot(subjset[0].matrix()["abs"].T)
# Out:
# [<matplotlib.lines.Line2D at 0x7fd2b89a2910>,
#  <matplotlib.lines.Line2D at 0x7fd2b8b99ad0>,
#  <matplotlib.lines.Line2D at 0x7fd2b8bf4f10>,
#  <matplotlib.lines.Line2D at 0x7fd2b885d1d0>,
#  <matplotlib.lines.Line2D at 0x7fd2b885d590>,
#  <matplotlib.lines.Line2D at 0x7fd2b885d8d0>,
#  <matplotlib.lines.Line2D at 0x7fd2b885dd50>,
#  <matplotlib.lines.Line2D at 0x7fd2b899e110>,
#  <matplotlib.lines.Line2D at 0x7fd2b880e4d0>,
#  <matplotlib.lines.Line2D at 0x7fd2b89f6890>]

# %%
subjset[0].read_depth()
# Out:
# array([25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000,
#        25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000,
#        25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000])

# %%
plt.plot([i.data.mean() for i in subjset[0].qpcr.values()])

# %%
np.array(traces[STRNAMES.LATENT_TRAJECTORY+f"_subj_{i}"]).shape
# Out:
# (15000, 10, 27)

# %%
np.percentile(np.array(traces[STRNAMES.LATENT_TRAJECTORY+f"_subj_{i}"]), [25,75], axis=0).shape
# Out:
# (2, 10, 27)

# %%
fig, ax = plt.subplots(2, 5, figsize=(20,4))

for i in range(10):
    ax.flatten()[i].plot(subjset[i].matrix()["abs"].T[:,0])
    ax1 = ax.flatten()[i].twinx()
    ax1.plot(md2.summary(np.array(traces[STRNAMES.LATENT_TRAJECTORY+f"_subj_{i}"]))["mean"].T[:,0], c="k")
    ax1.fill_between(np.arange(27), *np.percentile(np.array(traces[STRNAMES.LATENT_TRAJECTORY+f"_subj_{i}"]), [5,95], axis=0)[:,0], color="k", alpha=0.3)

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,6))

im1 = ax[0].imshow(ints, cmap="coolwarm", vmin=-np.max(np.abs(ints)), vmax=np.max(np.abs(ints)))
fig.colorbar(im1)

im2 = ax[1].imshow(ints_est*(generate_interation_bayes_factors_posthoc(traces)>10)+np.diag(np.diag(ints_est)), cmap="coolwarm", vmin=-np.max(np.abs(ints_est)), vmax=np.max(np.abs(ints_est)))
fig.colorbar(im2)

# %%
from scipy.stats import spearmanr, pearsonr

# %%
spearmanr(gr, gr_est)
# Out:
# SignificanceResult(statistic=np.float64(-0.1515151515151515), pvalue=np.float64(0.6760651759978539))

# %%
mcmc.graph[STRNAMES.PROCESSVAR].get_trace_from_disk().mean()
# Out:
# np.float64(0.19012891907758775)

# %%
spearmanr((ints).flatten(), (ints_est).flatten())
# Out:
# SignificanceResult(statistic=np.float64(0.66712359197748), pvalue=np.float64(3.4998005438560444e-14))

# %%
spearmanr((ints-np.diag(np.diag(ints))).flatten(), (ints_est-np.diag(np.diag(ints_est))).flatten())
# Out:
# SignificanceResult(statistic=np.float64(0.5535974798769446), pvalue=np.float64(2.3167629557750118e-09))

# %%
spearmanr((ints-np.diag(np.diag(ints))).flatten(), ((ints_est-np.diag(np.diag(ints_est)))*(md2.generate_interation_bayes_factors_posthoc(mcmc)>10)).flatten())
# Out:
# SignificanceResult(statistic=np.float64(0.747881320660978), pvalue=np.float64(3.888298164136079e-19))

# %%
spearmanr((ints).flatten(), ((ints_est-np.diag(np.diag(ints_est)))*(md2.generate_interation_bayes_factors_posthoc(mcmc)>10)+np.diag(np.diag(ints_est))).flatten())
# Out:
# SignificanceResult(statistic=np.float64(0.8226865066386722), pvalue=np.float64(8.93653331197679e-26))

# %%
pearsonr((ints-np.diag(np.diag(ints))).flatten(), (ints_est-np.diag(np.diag(ints_est))).flatten())
# Out:
# PearsonRResult(statistic=np.float64(0.7400269014111068), pvalue=np.float64(1.4164075709595746e-18))

# %%
pearsonr((ints-np.diag(np.diag(ints))).flatten(), ((ints_est-np.diag(np.diag(ints_est)))*(md2.generate_interation_bayes_factors_posthoc(mcmc)>10)).flatten())
# Out:
# PearsonRResult(statistic=np.float64(0.7883897417554289), pvalue=np.float64(2.1272455995785715e-22))

# %%
plt.imshow(np.sign(ints_est), cmap="coolwarm")

# %%
plt.imshow(np.sign(ints)+np.eye(10), cmap="coolwarm")

# %%
plt.imshow(np.sign(ints_est)*(md2.generate_interation_bayes_factors_posthoc(mcmc)>10), cmap="coolwarm")
